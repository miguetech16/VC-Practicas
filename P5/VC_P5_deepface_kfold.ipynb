# %%
import os
import cv2
import numpy as np
from deepface import DeepFace
#from deepface.commons import functions

from time import time

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
# Out:
# WARNING:tensorflow:From c:\Users\milit\anaconda3\envs\VC_P5\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 24-11-06 15:05:34 - Directory C:\Users\milit\.deepface has been created
# 24-11-06 15:05:34 - Directory C:\Users\milit\.deepface\weights has been created

# %% [markdown]
# # Definición de funciones

# %%
def GetSVMPredictions(X_train, X_test, y_train, y_test):
    
    print("+++++++++++++++++++++++++++++++++++++++++++\n")
    print("SVM Normalization...")
    scaler = MinMaxScaler()
    train_X = scaler.fit_transform(X_train)
    test_X = scaler.transform(X_test)

    print("SVM training...")
    t0 = time()
    parameters = {'C': [1e3, 5e3, 1e4, 5e4, 1e5],
                  'gamma': [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.1],}
    # Grid serach across parameter range
    clf = GridSearchCV(
        SVC(kernel='rbf', class_weight='balanced'), parameters, cv=5
    )
    clf = clf.fit(train_X, y_train)
    print("done in %0.3fs" % (time() - t0))
    print("Best estimator found by grid search:")
    print(clf.best_estimator_)


    print("Predicting")
    t0 = time()
    y_pred = clf.predict(test_X)
    print("done in %0.3fs" % (time() - t0))
    
    return y_pred, y_test

def GetKNNPredictions(k, X_train, X_test, y_train, y_test):
    
    t0 = time()
    # k = 5 
    model_px = KNeighborsClassifier(n_neighbors = k) 

    # fdtraining of model 
    model_px.fit(X_train, y_train) 
    print("done in %0.3fs" % (time() - t0))

    print("Predicting...")
    t0 = time()
    y_pred=model_px.predict(X_test)

    print("done in %0.3fs" % (time() - t0))
    
  
    return y_pred, y_test

# %%
def calc_embs(X, batch_size=2): #No usada desde 2024 en el código
    norm_images = prewhiten(X)
    pd = []
    for start in range(0, len(norm_images), batch_size):
        pd.append(model.predict_on_batch(norm_images[start:start+batch_size]))     #https://github.com/serengil/deepface/issues/819           
    return l2_normalize(np.concatenate(pd))

def l2_normalize(x, axis=-1, epsilon=1e-10):
    output = x / np.sqrt(np.maximum(np.sum(np.square(x), axis=axis, keepdims=True), epsilon))
    return output

def prewhiten(x):
    if x.ndim == 4:
        axis = (1, 2, 3)
        size = x[0].size
    elif x.ndim == 3:
        axis = (0, 1, 2)
        size = x.size
    else:
        raise ValueError('Dimension should be 3 or 4')

    mean = np.mean(x, axis=axis, keepdims=True)
    std = np.std(x, axis=axis, keepdims=True)
    std_adj = np.maximum(std, 1.0/np.sqrt(size))
    y = (x - mean) / std_adj
    return y


def LoadDataset(folder, ext):
    # Contador de número de clases del conjunto
    nclasses = 0
    # Contador de muestras por clase
    nperclass = []
    # Etiqueta de cada clase (nombre de la subcarpeta)
    classlabels = []
    # Inicializa estructuras de datos y sus correpondientes etiquetas
    X = []
    Y = []

    preprocessing = 0

    # Asume que en la ruta indicada hay una subcarpeta por clase
    for class_name in os.listdir(folder):
        # Cada subcarpeta implica una clase más
        nclasses += 1
        # Inicialmente esta clase no tiene muestras
        nsamples = 1    

        # Compone la ruta
        class_folder = os.path.join(folder, class_name)
        for file_name in os.listdir(class_folder):
            # Asume imágenes en formato ext
            if file_name.endswith(ext):
                # Lee la imagen
                image = cv2.imread (os.path.join(class_folder, file_name))  

                # Obtiene embeddings
                img1 = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)

                # Hasta 2023 usaba
                # Get embeddings after preprocessing
                #if preprocessing == 1:
                #    img_embedding = calc_embs(np.array([img1]))
                #else:
                #    img_embedding = model.predict(img1[None,...])

                #X.append(img_embedding[0])
                
                #Desde 2024
                embedding_objs = DeepFace.represent(img_path = img1,model_name  = "Facenet", enforce_detection = False)   
                img_embedding = embedding_objs[0]["embedding"]             

                X.append(img_embedding)

                # Añade etiqueta numérica de la muestra
                Y.append(nclasses-1)

                #Incrementa el número de muestras
                nsamples += 1

        nperclass.append(nsamples)
        classlabels.append(class_name)

    #Convierte a numpy array X e Y
    X = np.array(X,dtype='float32')
    Y = np.array(Y,dtype='float64')

    # Muestra datos del conjunto leído
    # Depuración
    print("Features")
    print(X.shape)
    print(Y.shape)
    # Obtiene número de muestras y características
    n_samples , n_features = X.shape
    # Obtiene nombres de las clases
    class_names = np.array(classlabels)
    n_classes = class_names.shape[0]
    
    return X, Y, n_samples, n_features, n_classes, classlabels, nperclass, class_names

# %% [markdown]
# # Carga conjuntos de datos
#
# Se proporciona la carpeta, a través de la variable folder, donde cada subcarpeta se corresponde con una clase.
# Cada clase contiene muestras en forma de imágenes jpg, todas del mismo tamaño. Obtiene embeddings Facenet

# %%
# Modelos disponibles ['VGG-Face', 'Facenet', 'OpenFace', 'DeepFace', 'DeepID', 'Dlib']
model = DeepFace.build_model("Facenet")
dim = model.input_shape

#MODIFICAR INDICANDO RUTA EN TU EQUIPO TRAS DESCAGAR DATOS DEL CAMPUS. EVITAR TILDES
folder = "DatabaseGender59x65" # RUTA EJEMPLO, MODIFICAR

print('Loading dataset')
X, Y, nsamples, class_name, nperclass, classlabels, width, height = LoadDataset(folder,'.jpg')

#Convierte a numpy array X e Y
X = np.array(X,dtype='float32')
Y = np.array(Y,dtype='float64')

# Obtiene número de muestras y características
n_samples , n_features = X.shape
# Obtiene nombres de las clases
class_names = np.array(classlabels)
n_classes = class_names.shape[0]

print("Dataset info:")
print("# samples: %d" % n_samples)
print("# features: %d" % n_features)
print("# classes: %d" % n_classes)
print("classes %s" % classlabels)
print("samples per class %s" % str(nperclass)[1:-1] )
# Out:
# Loading dataset
# Features
# (1184, 128)
# (1184,)
# Dataset info:
# # samples: 1184
# # features: 128
# # classes: 2
# classes ['Female', 'Male']
# samples per class

# %% [markdown]
# # Diseña conjunto experimental k-fold
#
# Divide los datos k veces en conjunto de entrenamiento y test

# %%
# StratifiedKFold
# Define el número de subconjuntos a considerar
kfold = 5
skf = StratifiedKFold(n_splits=kfold, random_state=4, shuffle=True)
#Distribución de muestras por fold
fold = 1
for train_index, test_index in skf.split(X, Y):
    #print("TRAIN:", train_index, "TEST:", test_index)
    print("Fold %d" % fold)
    print("# samples in training set %d" % train_index.shape[0])
    print("# samples in test set %d" % test_index.shape[0])
    fold += 1
# Out:
# Fold 1
# # samples in training set 947
# # samples in test set 237
# Fold 2
# # samples in training set 947
# # samples in test set 237
# Fold 3
# # samples in training set 947
# # samples in test set 237
# Fold 4
# # samples in training set 947
# # samples in test set 237
# Fold 5
# # samples in training set 948
# # samples in test set 236

# %% [markdown]
# # Lanza experimento

# %%
# Embeddings
precs_facenet_svm, recs_facenet_svm = [], []
precs_facenet_knn, recs_facenet_knn = [], []


# Recorre folds
fold = 1
while fold <= kfold:
    accs, precs, recs = [], [], []
    for train_index, test_index in skf.split(X, Y):
        #print("TRAIN:", train_index, "TEST:", test_index)
        print("***\nFold %d" % fold)
        #División de muestras de entreno y test
        X_train, X_test = X[train_index], X[test_index]
        #Etiquetas de las muestras
        y_train, y_test = Y[train_index], Y[test_index]


        #Facenet+KNN
        y_pred, y_test = GetKNNPredictions(11, X_train, X_test,y_train, y_test)
        print("\nFacenet+KNN Metrics")
        precs_facenet_knn.append(precision_score(y_test, y_pred, average='weighted'))
        recs_facenet_knn.append(recall_score(y_test, y_pred, average='weighted'))
        print(classification_report(y_test, y_pred, target_names=class_names))
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes)))      
            
        #Facenet+SVM
        y_pred, y_test = GetSVMPredictions(X_train, X_test,y_train, y_test)
        print("\nFacenet+SVM Metrics")
        precs_facenet_svm.append(precision_score(y_test, y_pred, average='weighted'))
        recs_facenet_svm.append(recall_score(y_test, y_pred, average='weighted'))
        print(classification_report(y_test, y_pred, target_names=class_names))
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes)))        
    

    fold += 1

print("Facenet+KNN Mean Precision:  %0.3f, Mean Recall:  %0.3f" % ( np.mean(precs_facenet_knn) , np.mean(recs_facenet_knn) ))
print("Facenet+SVM Mean Precision:  %0.3f, Mean Recall:  %0.3f" % ( np.mean(precs_facenet_svm) , np.mean(recs_facenet_svm) ))
# Out:
# ***
# Fold 1
# done in 0.002s
# Predicting...
# done in 0.460s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.72      0.96      0.82       117
#         Male       0.94      0.63      0.76       120
#
#     accuracy                           0.79       237
#    macro avg       0.83      0.80      0.79       237
# weighted avg       0.83      0.79      0.79       237
#
# [[112   5]
#  [ 44  76]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 7.045s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.91      0.91      0.91       117
#         Male       0.91      0.91      0.91       120
#
#     accuracy                           0.91       237
#    macro avg       0.91      0.91      0.91       237
# weighted avg       0.91      0.91      0.91       237
#
# [[106  11]
#  [ 11 109]]
# ***
# Fold 1
# done in 0.001s
# Predicting...
# done in 0.007s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.75      0.99      0.85       117
#         Male       0.99      0.68      0.80       120
#
#     accuracy                           0.83       237
#    macro avg       0.87      0.83      0.83       237
# weighted avg       0.87      0.83      0.83       237
#
# [[116   1]
#  [ 39  81]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 7.534s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.93      0.97      0.95       117
#         Male       0.97      0.93      0.94       120
#
#     accuracy                           0.95       237
#    macro avg       0.95      0.95      0.95       237
# weighted avg       0.95      0.95      0.95       237
#
# [[113   4]
#  [  9 111]]
# ***
# Fold 1
# done in 0.001s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.81      0.98      0.89       116
#         Male       0.98      0.79      0.87       121
#
#     accuracy                           0.88       237
#    macro avg       0.90      0.88      0.88       237
# weighted avg       0.90      0.88      0.88       237
#
# [[114   2]
#  [ 26  95]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.415s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.92      0.95      0.94       116
#         Male       0.95      0.93      0.94       121
#
#     accuracy                           0.94       237
#    macro avg       0.94      0.94      0.94       237
# weighted avg       0.94      0.94      0.94       237
#
# [[110   6]
#  [  9 112]]
# ***
# Fold 1
# done in 0.001s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.71      0.95      0.81       116
#         Male       0.93      0.63      0.75       121
#
#     accuracy                           0.78       237
#    macro avg       0.82      0.79      0.78       237
# weighted avg       0.82      0.78      0.78       237
#
# [[110   6]
#  [ 45  76]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.186s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.005)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.92      0.94      0.93       116
#         Male       0.94      0.92      0.93       121
#
#     accuracy                           0.93       237
#    macro avg       0.93      0.93      0.93       237
# weighted avg       0.93      0.93      0.93       237
#
# [[109   7]
#  [ 10 111]]
# ***
# Fold 1
# done in 0.001s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.73      0.98      0.84       116
#         Male       0.97      0.64      0.77       120
#
#     accuracy                           0.81       236
#    macro avg       0.85      0.81      0.80       236
# weighted avg       0.85      0.81      0.80       236
#
# [[114   2]
#  [ 43  77]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.677s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.95      0.93      0.94       116
#         Male       0.93      0.95      0.94       120
#
#     accuracy                           0.94       236
#    macro avg       0.94      0.94      0.94       236
# weighted avg       0.94      0.94      0.94       236
#
# [[108   8]
#  [  6 114]]
# ***
# Fold 2
# done in 0.001s
# Predicting...
# done in 0.006s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.72      0.96      0.82       117
#         Male       0.94      0.63      0.76       120
#
#     accuracy                           0.79       237
#    macro avg       0.83      0.80      0.79       237
# weighted avg       0.83      0.79      0.79       237
#
# [[112   5]
#  [ 44  76]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.555s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.009s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.91      0.91      0.91       117
#         Male       0.91      0.91      0.91       120
#
#     accuracy                           0.91       237
#    macro avg       0.91      0.91      0.91       237
# weighted avg       0.91      0.91      0.91       237
#
# [[106  11]
#  [ 11 109]]
# ***
# Fold 2
# done in 0.001s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.75      0.99      0.85       117
#         Male       0.99      0.68      0.80       120
#
#     accuracy                           0.83       237
#    macro avg       0.87      0.83      0.83       237
# weighted avg       0.87      0.83      0.83       237
#
# [[116   1]
#  [ 39  81]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 7.157s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.010s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.93      0.97      0.95       117
#         Male       0.97      0.93      0.94       120
#
#     accuracy                           0.95       237
#    macro avg       0.95      0.95      0.95       237
# weighted avg       0.95      0.95      0.95       237
#
# [[113   4]
#  [  9 111]]
# ***
# Fold 2
# done in 0.001s
# Predicting...
# done in 0.006s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.81      0.98      0.89       116
#         Male       0.98      0.79      0.87       121
#
#     accuracy                           0.88       237
#    macro avg       0.90      0.88      0.88       237
# weighted avg       0.90      0.88      0.88       237
#
# [[114   2]
#  [ 26  95]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 7.414s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.010s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.92      0.95      0.94       116
#         Male       0.95      0.93      0.94       121
#
#     accuracy                           0.94       237
#    macro avg       0.94      0.94      0.94       237
# weighted avg       0.94      0.94      0.94       237
#
# [[110   6]
#  [  9 112]]
# ***
# Fold 2
# done in 0.001s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.71      0.95      0.81       116
#         Male       0.93      0.63      0.75       121
#
#     accuracy                           0.78       237
#    macro avg       0.82      0.79      0.78       237
# weighted avg       0.82      0.78      0.78       237
#
# [[110   6]
#  [ 45  76]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.750s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.005)
# Predicting
# done in 0.007s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.92      0.94      0.93       116
#         Male       0.94      0.92      0.93       121
#
#     accuracy                           0.93       237
#    macro avg       0.93      0.93      0.93       237
# weighted avg       0.93      0.93      0.93       237
#
# [[109   7]
#  [ 10 111]]
# ***
# Fold 2
# done in 0.000s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.73      0.98      0.84       116
#         Male       0.97      0.64      0.77       120
#
#     accuracy                           0.81       236
#    macro avg       0.85      0.81      0.80       236
# weighted avg       0.85      0.81      0.80       236
#
# [[114   2]
#  [ 43  77]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 7.754s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.95      0.93      0.94       116
#         Male       0.93      0.95      0.94       120
#
#     accuracy                           0.94       236
#    macro avg       0.94      0.94      0.94       236
# weighted avg       0.94      0.94      0.94       236
#
# [[108   8]
#  [  6 114]]
# ***
# Fold 3
# done in 0.000s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.72      0.96      0.82       117
#         Male       0.94      0.63      0.76       120
#
#     accuracy                           0.79       237
#    macro avg       0.83      0.80      0.79       237
# weighted avg       0.83      0.79      0.79       237
#
# [[112   5]
#  [ 44  76]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.748s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.91      0.91      0.91       117
#         Male       0.91      0.91      0.91       120
#
#     accuracy                           0.91       237
#    macro avg       0.91      0.91      0.91       237
# weighted avg       0.91      0.91      0.91       237
#
# [[106  11]
#  [ 11 109]]
# ***
# Fold 3
# done in 0.001s
# Predicting...
# done in 0.006s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.75      0.99      0.85       117
#         Male       0.99      0.68      0.80       120
#
#     accuracy                           0.83       237
#    macro avg       0.87      0.83      0.83       237
# weighted avg       0.87      0.83      0.83       237
#
# [[116   1]
#  [ 39  81]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 7.237s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.009s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.93      0.97      0.95       117
#         Male       0.97      0.93      0.94       120
#
#     accuracy                           0.95       237
#    macro avg       0.95      0.95      0.95       237
# weighted avg       0.95      0.95      0.95       237
#
# [[113   4]
#  [  9 111]]
# ***
# Fold 3
# done in 0.001s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.81      0.98      0.89       116
#         Male       0.98      0.79      0.87       121
#
#     accuracy                           0.88       237
#    macro avg       0.90      0.88      0.88       237
# weighted avg       0.90      0.88      0.88       237
#
# [[114   2]
#  [ 26  95]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.513s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.92      0.95      0.94       116
#         Male       0.95      0.93      0.94       121
#
#     accuracy                           0.94       237
#    macro avg       0.94      0.94      0.94       237
# weighted avg       0.94      0.94      0.94       237
#
# [[110   6]
#  [  9 112]]
# ***
# Fold 3
# done in 0.001s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.71      0.95      0.81       116
#         Male       0.93      0.63      0.75       121
#
#     accuracy                           0.78       237
#    macro avg       0.82      0.79      0.78       237
# weighted avg       0.82      0.78      0.78       237
#
# [[110   6]
#  [ 45  76]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.325s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.005)
# Predicting
# done in 0.006s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.92      0.94      0.93       116
#         Male       0.94      0.92      0.93       121
#
#     accuracy                           0.93       237
#    macro avg       0.93      0.93      0.93       237
# weighted avg       0.93      0.93      0.93       237
#
# [[109   7]
#  [ 10 111]]
# ***
# Fold 3
# done in 0.000s
# Predicting...
# done in 0.006s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.73      0.98      0.84       116
#         Male       0.97      0.64      0.77       120
#
#     accuracy                           0.81       236
#    macro avg       0.85      0.81      0.80       236
# weighted avg       0.85      0.81      0.80       236
#
# [[114   2]
#  [ 43  77]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.669s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.95      0.93      0.94       116
#         Male       0.93      0.95      0.94       120
#
#     accuracy                           0.94       236
#    macro avg       0.94      0.94      0.94       236
# weighted avg       0.94      0.94      0.94       236
#
# [[108   8]
#  [  6 114]]
# ***
# Fold 4
# done in 0.001s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.72      0.96      0.82       117
#         Male       0.94      0.63      0.76       120
#
#     accuracy                           0.79       237
#    macro avg       0.83      0.80      0.79       237
# weighted avg       0.83      0.79      0.79       237
#
# [[112   5]
#  [ 44  76]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.260s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.91      0.91      0.91       117
#         Male       0.91      0.91      0.91       120
#
#     accuracy                           0.91       237
#    macro avg       0.91      0.91      0.91       237
# weighted avg       0.91      0.91      0.91       237
#
# [[106  11]
#  [ 11 109]]
# ***
# Fold 4
# done in 0.000s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.75      0.99      0.85       117
#         Male       0.99      0.68      0.80       120
#
#     accuracy                           0.83       237
#    macro avg       0.87      0.83      0.83       237
# weighted avg       0.87      0.83      0.83       237
#
# [[116   1]
#  [ 39  81]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.976s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.93      0.97      0.95       117
#         Male       0.97      0.93      0.94       120
#
#     accuracy                           0.95       237
#    macro avg       0.95      0.95      0.95       237
# weighted avg       0.95      0.95      0.95       237
#
# [[113   4]
#  [  9 111]]
# ***
# Fold 4
# done in 0.000s
# Predicting...
# done in 0.006s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.81      0.98      0.89       116
#         Male       0.98      0.79      0.87       121
#
#     accuracy                           0.88       237
#    macro avg       0.90      0.88      0.88       237
# weighted avg       0.90      0.88      0.88       237
#
# [[114   2]
#  [ 26  95]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.353s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.92      0.95      0.94       116
#         Male       0.95      0.93      0.94       121
#
#     accuracy                           0.94       237
#    macro avg       0.94      0.94      0.94       237
# weighted avg       0.94      0.94      0.94       237
#
# [[110   6]
#  [  9 112]]
# ***
# Fold 4
# done in 0.001s
# Predicting...
# done in 0.006s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.71      0.95      0.81       116
#         Male       0.93      0.63      0.75       121
#
#     accuracy                           0.78       237
#    macro avg       0.82      0.79      0.78       237
# weighted avg       0.82      0.78      0.78       237
#
# [[110   6]
#  [ 45  76]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.016s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.005)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.92      0.94      0.93       116
#         Male       0.94      0.92      0.93       121
#
#     accuracy                           0.93       237
#    macro avg       0.93      0.93      0.93       237
# weighted avg       0.93      0.93      0.93       237
#
# [[109   7]
#  [ 10 111]]
# ***
# Fold 4
# done in 0.000s
# Predicting...
# done in 0.006s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.73      0.98      0.84       116
#         Male       0.97      0.64      0.77       120
#
#     accuracy                           0.81       236
#    macro avg       0.85      0.81      0.80       236
# weighted avg       0.85      0.81      0.80       236
#
# [[114   2]
#  [ 43  77]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.683s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.95      0.93      0.94       116
#         Male       0.93      0.95      0.94       120
#
#     accuracy                           0.94       236
#    macro avg       0.94      0.94      0.94       236
# weighted avg       0.94      0.94      0.94       236
#
# [[108   8]
#  [  6 114]]
# ***
# Fold 5
# done in 0.001s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.72      0.96      0.82       117
#         Male       0.94      0.63      0.76       120
#
#     accuracy                           0.79       237
#    macro avg       0.83      0.80      0.79       237
# weighted avg       0.83      0.79      0.79       237
#
# [[112   5]
#  [ 44  76]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.416s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.007s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.91      0.91      0.91       117
#         Male       0.91      0.91      0.91       120
#
#     accuracy                           0.91       237
#    macro avg       0.91      0.91      0.91       237
# weighted avg       0.91      0.91      0.91       237
#
# [[106  11]
#  [ 11 109]]
# ***
# Fold 5
# done in 0.001s
# Predicting...
# done in 0.005s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.75      0.99      0.85       117
#         Male       0.99      0.68      0.80       120
#
#     accuracy                           0.83       237
#    macro avg       0.87      0.83      0.83       237
# weighted avg       0.87      0.83      0.83       237
#
# [[116   1]
#  [ 39  81]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 7.349s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.009s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.93      0.97      0.95       117
#         Male       0.97      0.93      0.94       120
#
#     accuracy                           0.95       237
#    macro avg       0.95      0.95      0.95       237
# weighted avg       0.95      0.95      0.95       237
#
# [[113   4]
#  [  9 111]]
# ***
# Fold 5
# done in 0.000s
# Predicting...
# done in 0.007s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.81      0.98      0.89       116
#         Male       0.98      0.79      0.87       121
#
#     accuracy                           0.88       237
#    macro avg       0.90      0.88      0.88       237
# weighted avg       0.90      0.88      0.88       237
#
# [[114   2]
#  [ 26  95]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.254s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.009s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.92      0.95      0.94       116
#         Male       0.95      0.93      0.94       121
#
#     accuracy                           0.94       237
#    macro avg       0.94      0.94      0.94       237
# weighted avg       0.94      0.94      0.94       237
#
# [[110   6]
#  [  9 112]]
# ***
# Fold 5
# done in 0.001s
# Predicting...
# done in 0.006s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.71      0.95      0.81       116
#         Male       0.93      0.63      0.75       121
#
#     accuracy                           0.78       237
#    macro avg       0.82      0.79      0.78       237
# weighted avg       0.82      0.78      0.78       237
#
# [[110   6]
#  [ 45  76]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.082s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.005)
# Predicting
# done in 0.008s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.92      0.94      0.93       116
#         Male       0.94      0.92      0.93       121
#
#     accuracy                           0.93       237
#    macro avg       0.93      0.93      0.93       237
# weighted avg       0.93      0.93      0.93       237
#
# [[109   7]
#  [ 10 111]]
# ***
# Fold 5
# done in 0.001s
# Predicting...
# done in 0.006s
#
# Facenet+KNN Metrics
#               precision    recall  f1-score   support
#
#       Female       0.73      0.98      0.84       116
#         Male       0.97      0.64      0.77       120
#
#     accuracy                           0.81       236
#    macro avg       0.85      0.81      0.80       236
# weighted avg       0.85      0.81      0.80       236
#
# [[114   2]
#  [ 43  77]]
# +++++++++++++++++++++++++++++++++++++++++++
#
# SVM Normalization...
# SVM training...
# done in 6.646s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.010s
#
# Facenet+SVM Metrics
#               precision    recall  f1-score   support
#
#       Female       0.95      0.93      0.94       116
#         Male       0.93      0.95      0.94       120
#
#     accuracy                           0.94       236
#    macro avg       0.94      0.94      0.94       236
# weighted avg       0.94      0.94      0.94       236
#
# [[108   8]
#  [  6 114]]
# Facenet+KNN Mean Precision:  0.854, Mean Recall:  0.820
# Facenet+SVM Mean Precision:  0.932, Mean Recall:  0.932
